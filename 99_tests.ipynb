# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from birds_utils import get_fourier_weights, get_keras_fourier_model

# %%
window_size = 1024
cos_weights, sin_weights = get_fourier_weights(window_size)

# %%
cos_weights.shape
# Out:
# (512, 1024)

# %%
model.get_layer('cos').get_weights()[0].shape
# Out:
# (1024, 1, 512)

# %%
model = get_keras_fourier_model(window_size)

# %%
from matplotlib import pyplot as plt
#plt.plot(model.get_layer('cos').get_weights()[0][:, 0])

# %%
plt.plot(model.get_layer('cos').get_weights()[0][:,0,0])
plt.plot(model.get_layer('cos').get_weights()[0][:,0,1])
plt.plot(model.get_layer('cos').get_weights()[0][:,0,2])
