# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pydub import AudioSegment
import pandas as pd
import IPython.display as ipd
from glob import glob
import os
from collections import Counter

# %%
FOLDER = '/home/usuario/birds/birdsong-recognition/'
TRAIN_FOLDER = FOLDER + 'train_audio/'

train = pd.read_csv(FOLDER+'train.csv')

# %%
Counter(train['ebird_code']).most_common()
# Out:
# [('aldfly', 100),
#  ('amecro', 100),
#  ('amegfi', 100),
#  ('amepip', 100),
#  ('amered', 100),
#  ('amerob', 100),
#  ('annhum', 100),
#  ('astfly', 100),
#  ('balori', 100),
#  ('banswa', 100),
#  ('barswa', 100),
#  ('bewwre', 100),
#  ('bkbwar', 100),
#  ('bkcchi', 100),
#  ('bkhgro', 100),
#  ('bkpwar', 100),
#  ('blkpho', 100),
#  ('blugrb1', 100),
#  ('blujay', 100),
#  ('bnhcow', 100),
#  ('boboli', 100),
#  ('brdowl', 100),
#  ('brespa', 100),
#  ('brncre', 100),
#  ('brnthr', 100),
#  ('btnwar', 100),
#  ('buggna', 100),
#  ('buhvir', 100),
#  ('bulori', 100),
#  ('bushti', 100),
#  ('cacwre', 100),
#  ('cangoo', 100),
#  ('canwar', 100),
#  ('canwre', 100),
#  ('carwre', 100),
#  ('caster1', 100),
#  ('chispa', 100),
#  ('chswar', 100),
#  ('comgra', 100),
#  ('comrav', 100),
#  ('comred', 100),
#  ('comter', 100),
#  ('comyel', 100),
#  ('daejun', 100),
#  ('dowwoo', 100),
#  ('easmea', 100),
#  ('eastow', 100),
#  ('eawpew', 100),
#  ('eucdov', 100),
# ...

# %%
row
# Out:
# ebird_code          aldfly
# filename      XC134874.mp3
# Name: 0, dtype: object

# %%
incomplete_ebird_code = []
for i in range(len(train)):
    row = train.iloc[i]
    filename = TRAIN_FOLDER+row['ebird_code']+'/'+row['filename']
    if not os.path.exists(filename):
        incomplete_ebird_code.append(row['ebird_code'])

# %%
print(incomplete_ebird_code[:200])
# Out:
# ['warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir', 'warvir
# ...
