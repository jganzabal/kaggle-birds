# %%
# %load_ext autoreload
# %autoreload 2/home/usuario/
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from birds_utils import get_bin_audio
import glob as glob
from matplotlib import pyplot as plt
import numpy as np

# %%
FOLDER = './dataset/bin_22050_32/'

# %%
cl = 'aldfly'

# %%
file = FOLDER + cl + '/XC134874.mp3.bin'

# %%
audio = get_bin_audio(file, 'float32')

# %%
audio.std()
# Out:
# 1.0

# %%
plt.plot(audio)

# %%
correlation = np.correlate(audio, audio, mode='same')

# %%
plt.plot(correlation)
plt.show()
plt.plot(audio)

# %%
len(correlation), len(audio)
# Out:
# (562011, 562011)
